# %%
import pandas as pd

#資料源自中央氣象局地震測報中心
eq = pd.read_csv("earthquake202301.csv",encoding='big5')
eq
# Out:
#     2023年1月 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        編號       地震時間     經度(度E)     緯度(度N)       芮氏規模     深度(km)
# 1   小區域有感地震      1月29日    120.798    23.2082        3.2        4.7
# 2   小區域有感地震      1月27日    121.238    23.2665        3.5       16.8
# 3   小區域有感地震      1月24日    121.276    23.0717        3.7        7.7
# 4   小區域有感地震      1月24日    121.291    23.4362        3.8       11.4
# 5   小區域有感地震      1月22日    121.913    24.4312        3.6       13.4
# 6   小區域有感地震      1月21日    120.856    24.3787        3.6        5.4
# 7   小區域有感地震      1月21日    121.241    23.2627        3.6       16.8
# 8   小區域有感地震      1月21日    121.767    23.7825        4.1       15.9
# 9   小區域有感地震      1月20日     120.27    23.2468        3.1       14.6
# 10    第005號      1月20日    121.516    24.0478        4.4       19.7
# 11  小區域有感地震      1月20日    121.777    24.0725        4.1       32.5
# 12  小區域有感地震      1月19日    121.163    23.0958        3.7       13.8
# ...
