# %%
import pandas as pd

#資料源自中央氣象局地震測報中心，此為2023年1月的資料
eq = pd.read_csv("earthquake202301.csv",encoding='big5')
eq
# Out:
#          編號        地震日期   地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 0   小區域有感地震  2023年1月29日  23:15  120.798  23.2082   3.2     4.7
# 1   小區域有感地震  2023年1月27日   6:40  121.238  23.2665   3.5    16.8
# 2   小區域有感地震  2023年1月24日  22:37  121.276  23.0717   3.7     7.7
# 3   小區域有感地震  2023年1月24日  12:17  121.291  23.4362   3.8    11.4
# 4   小區域有感地震  2023年1月22日   6:13  121.913  24.4312   3.6    13.4
# 5   小區域有感地震  2023年1月21日  14:05  120.856  24.3787   3.6     5.4
# 6   小區域有感地震  2023年1月21日  14:04  121.241  23.2627   3.6    16.8
# 7   小區域有感地震  2023年1月21日   8:05  121.767  23.7825   4.1    15.9
# 8   小區域有感地震  2023年1月20日  17:24  120.270  23.2468   3.1    14.6
# 9     第005號  2023年1月20日  10:56  121.516  24.0478   4.4    19.7
# 10  小區域有感地震  2023年1月20日   2:43  121.777  24.0725   4.1    32.5
# 11  小區域有感地震  2023年1月19日  10:09  121.163  23.0958   3.7    13.8
# 12  小區域有感地震  2023年1月16日  22:03  122.326  24.0063   4.7    23.4
# 13  小區域有感地震  2023年1月15日  15:48  121.163  24.9075   3.1     4.2
# ...

# %%
#第一題
#列出所有芮氏規模大於等於4的資料，並且回答共有幾筆

#使用布林索引篩選資料
Richter_scale = eq[eq['芮氏規模'] >= 5]

#所有芮氏規模大於等於5的列數
Rs_rows = len(Richter_scale)

print('共有',Rs_rows,'筆資料')
Richter_scale
# Out:
# 共有 2 筆資料
#          編號        地震日期   地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 14  小區域有感地震  2023年1月15日   3:40  122.583  25.1852   5.3   171.1
# 17  小區域有感地震  2023年1月13日  23:02  122.336  24.0407   5.0    24.2
#
#                                         位置
# 14  基隆市政府東方  84.7  公里 (位於臺灣東北部海域)(臺灣東北部海域)
# 17    花蓮縣政府東方  73.0  公里 (位於臺灣東部海域)(臺灣東部海域)

# %%
#第二題
#問震源深度>30km，即列出除極淺地震外的其餘地震資料

eq_depth = eq[eq['深度(km)']>30]
eq_depth_rows = len(eq_depth)
print('震源深度>30km：共有',eq_depth_rows,'筆資料')
eq_depth
# Out:
# 震源深度>30km：共有 4 筆資料
#          編號        地震日期   地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 10  小區域有感地震  2023年1月20日   2:43  121.777  24.0725   4.1    32.5
# 14  小區域有感地震  2023年1月15日   3:40  122.583  25.1852   5.3   171.1
# 23  小區域有感地震  2023年1月11日   3:22  121.308  23.1485   4.0    33.9
# 31  小區域有感地震   2023年1月5日  12:59  121.587  23.2297   4.5    39.7
#
#                                         位置
# 10  花蓮縣政府東北東方  18.3  公里 (位於臺灣東部海域)(臺灣東部海域)
# 14  基隆市政府東方  84.7  公里 (位於臺灣東北部海域)(臺灣東北部海域)
# 23  花蓮縣政府南南西方  98.6  公里 (位於花蓮縣富里鄉)(花蓮縣富里鄉)
# 31   臺東縣政府東北方  69.0  公里 (位於臺灣東部海域)(臺灣東部海域)

# %%
#第三題
#列出震央在臺灣東部海域的所有地震

occur_e = eq[eq['位置'].str.contains('臺灣東部海域')] #str提供對Series的每個元素進行操作的字串方法
occur_e_total = len(occur_e)
print('震央在臺灣東部海域的有',occur_e_total,'筆')
occur_e
# Out:
# 震央在臺灣東部海域的有 9 筆
#          編號        地震日期   地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 4   小區域有感地震  2023年1月22日   6:13  121.913  24.4312   3.6    13.4
# 7   小區域有感地震  2023年1月21日   8:05  121.767  23.7825   4.1    15.9
# 10  小區域有感地震  2023年1月20日   2:43  121.777  24.0725   4.1    32.5
# 12  小區域有感地震  2023年1月16日  22:03  122.326  24.0063   4.7    23.4
# 15  小區域有感地震  2023年1月14日  14:02  121.691  23.8367   3.9    21.7
# 17  小區域有感地震  2023年1月13日  23:02  122.336  24.0407   5.0    24.2
# 29  小區域有感地震   2023年1月6日   2:02  122.040  24.8863   4.2    13.5
# 30  小區域有感地震   2023年1月6日   1:11  122.038  24.8852   4.4    11.0
# 31  小區域有感地震   2023年1月5日  12:59  121.587  23.2297   4.5    39.7
#
#                                         位置
# 4   宜蘭縣政府南南東方  36.5  公里 (位於臺灣東部海域)(臺灣東部海域)
# 7    花蓮縣政府東南方  27.5  公里 (位於臺灣東部海域)(臺灣東部海域)
# 10  花蓮縣政府東北東方  18.3  公里 (位於臺灣東部海域)(臺灣東部海域)
# 12    花蓮縣政府東方  71.9  公里 (位於臺灣東部海域)(臺灣東部海域)
# 15  花蓮縣政府南南東方  18.5  公里 (位於臺灣東部海域)(臺灣東部海域)
# 17    花蓮縣政府東方  73.0  公里 (位於臺灣東部海域)(臺灣東部海域)
# ...

# %%
#第四題
#列出發生在台灣最東邊的一個地震

#astype是 pandas 中的一個方法，用於將 pandas 對象轉換為指定的數據類型
#以防經度可能為string，將經度轉換為浮點數
eq['經度(度E)'] = eq['經度(度E)'].astype(float)
#loc方法用於基於索引或條件選擇資料
#name屬性會返回所選資料行的索引值，即地震事件的編號
most_e = eq.loc[eq['經度(度E)'].idxmax()].name
eq.loc[most_e]
# Out:
# 編號                                       小區域有感地震
# 地震日期                                  2023年1月15日
# 地震時間                                        3:40
# 經度(度E)                                   122.583
# 緯度(度N)                                   25.1852
# 芮氏規模                                         5.3
# 深度(km)                                     171.1
# 位置        基隆市政府東方  84.7  公里 (位於臺灣東北部海域)(臺灣東北部海域)
# Name: 14, dtype: object

# %%
#第五題
#列出發生於台灣最北邊及最南邊的地震

eq['緯度(度N)'] = eq['緯度(度N)'].astype(float)
most_s = eq.loc[eq['緯度(度N)'].idxmin()].name
most_n = eq.loc[eq['緯度(度N)'].idxmax()].name
print(eq.loc[most_s])
print(eq.loc[most_n])
# Out:
# 編號                                       小區域有感地震
# 地震日期                                  2023年1月12日
# 地震時間                                       13:15
# 經度(度E)                                   121.042
# 緯度(度N)                                    22.066
# 芮氏規模                                         4.1
# 深度(km)                                      25.2
# 位置        臺東縣政府南方  77.1  公里 (位於臺灣東南部海域)(臺灣東南部海域)
# Name: 20, dtype: object
# 編號                                       小區域有感地震
# 地震日期                                  2023年1月15日
# 地震時間                                        3:40
# 經度(度E)                                   122.583
# 緯度(度N)                                   25.1852
# 芮氏規模                                         5.3
# 深度(km)                                     171.1
# 位置        基隆市政府東方  84.7  公里 (位於臺灣東北部海域)(臺灣東北部海域)
# Name: 14, dtype: object

# %%
#第六題
#列出編號為數字紀錄的地震資料

#\d用於匹配任何數字字符
number = eq[eq['編號'].astype(str).str.contains('\d')]
number
# Out:
#        編號        地震日期   地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 9   第005號  2023年1月20日  10:56  121.516  24.0478   4.4    19.7
# 19  第004號  2023年1月12日  13:15  120.660  22.8345   4.4    19.6
# 22  第003號  2023年1月11日  12:42  121.465  23.2245   4.8    29.2
# 25  第002號   2023年1月9日  19:31  121.265  23.3835   4.7    11.5
# 28  第001號   2023年1月7日  19:21  121.326  23.5553   4.7    15.2
#
#                                          位置
# 9    花蓮縣政府西北西方  12.3  公里 (位於花蓮縣秀林鄉)(花蓮縣秀林鄉)
# 19  屏東縣政府東北方  24.4  公里 (位於屏東縣三地門鄉)(屏東縣三地門鄉)
# 22      臺東縣政府東北方  61.2  公里 (位於臺東縣近海)(臺東縣近海)
# 25   花蓮縣政府南南西方  76.4  公里 (位於花蓮縣卓溪鄉)(花蓮縣卓溪鄉)
# 28    花蓮縣政府西南方  56.8  公里 (位於花蓮縣萬榮鄉)(花蓮縣萬榮鄉)

# %%
#第七題
#本月哪個縣市最常發生地震

location = eq[eq['位置'].str.contains('花蓮縣')]
Hualien_total = len(location)
print("2023年1月在花蓮縣發生:", Hualien_total,"起地震")
location
# Out:
# 2023年1月在花蓮縣發生: 18 起地震
#          編號        地震日期   地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 1   小區域有感地震  2023年1月27日   6:40  121.238  23.2665   3.5    16.8
# 3   小區域有感地震  2023年1月24日  12:17  121.291  23.4362   3.8    11.4
# 6   小區域有感地震  2023年1月21日  14:04  121.241  23.2627   3.6    16.8
# 7   小區域有感地震  2023年1月21日   8:05  121.767  23.7825   4.1    15.9
# 9     第005號  2023年1月20日  10:56  121.516  24.0478   4.4    19.7
# 10  小區域有感地震  2023年1月20日   2:43  121.777  24.0725   4.1    32.5
# 12  小區域有感地震  2023年1月16日  22:03  122.326  24.0063   4.7    23.4
# 15  小區域有感地震  2023年1月14日  14:02  121.691  23.8367   3.9    21.7
# 16  小區域有感地震  2023年1月14日   0:41  121.702  24.3215   3.2     8.0
# 17  小區域有感地震  2023年1月13日  23:02  122.336  24.0407   5.0    24.2
# 23  小區域有感地震  2023年1月11日   3:22  121.308  23.1485   4.0    33.9
# 24  小區域有感地震  2023年1月10日  22:53  121.735  24.2123   3.3    13.5
# 25    第002號   2023年1月9日  19:31  121.265  23.3835   4.7    11.5
# ...

# %%
#第八題
eq['地震時間'] = pd.to_datetime(eq['地震時間'],format='%H:%M')

#dt.hour是日期時間列的一個屬性，它提取日期時間值的小時部分
time_0to6 = eq[(eq['地震時間'].dt.hour >= 0) & (eq['地震時間'].dt.hour < 6)]
occur_time_0to6 = len(time_0to6)

print('發生於凌晨零點至早上六點之間的地震共',occur_time_0to6,'筆')
time_0to6
# Out:
# 發生於凌晨零點至早上六點之間的地震共 11 筆
#          編號        地震日期                地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 10  小區域有感地震  2023年1月20日 1900-01-01 02:43:00  121.777  24.0725   4.1    32.5
# 14  小區域有感地震  2023年1月15日 1900-01-01 03:40:00  122.583  25.1852   5.3   171.1
# 16  小區域有感地震  2023年1月14日 1900-01-01 00:41:00  121.702  24.3215   3.2     8.0
# 23  小區域有感地震  2023年1月11日 1900-01-01 03:22:00  121.308  23.1485   4.0    33.9
# 26  小區域有感地震   2023年1月9日 1900-01-01 01:13:00  120.546  23.0953   4.0    12.0
# 29  小區域有感地震   2023年1月6日 1900-01-01 02:02:00  122.040  24.8863   4.2    13.5
# 30  小區域有感地震   2023年1月6日 1900-01-01 01:11:00  122.038  24.8852   4.4    11.0
# 34  小區域有感地震   2023年1月3日 1900-01-01 05:46:00  120.341  23.1012   3.7    17.3
# 35  小區域有感地震   2023年1月3日 1900-01-01 05:46:00  120.333  23.0953   3.5    16.9
# 36  小區域有感地震   2023年1月3日 1900-01-01 05:19:00  121.544  23.7838   4.3    17.5
# 37  小區域有感地震   2023年1月3日 1900-01-01 05:06:00  121.552  23.7808   3.9    17.8
#
# ...

# %%
#第九題
#列出發生最多地震的一天，並且顯示共發生幾次

eq['地震日期'] = pd.to_datetime(eq['地震日期'],format='%Y年%m月%d日')
#將地震日期的欄位轉換為 Pandas 的日期時間格式，使用pd.to_datetime()
#日期欄位內注意格式 format程式碼需打出年月日
eq_count = eq.groupby('地震日期').size()
#groupby對日期進行分組，將相同日期的地震事件放在同一個組裡
#size 方法計算每個組的大小，即每天發生地震的次數
most_eqs_date = eq_count.idxmax()
#idxmax會返回序列中值最大的元素對應的索引 (index)

print('發生地震最多的日期為：', most_eqs_date.date(), '，共發生了', eq_count[most_eqs_date], '次地震')
# Out:
# 發生地震最多的日期為： 2023-01-03 ，共發生了 5 次地震

# %%
#第十題
#找出一天內發生兩起或以上且時間相同的地震紀錄，即找出地震日期欄位內相同且同時地震時間欄位內相同的資料

eq['地震日期'] = pd.to_datetime(eq['地震日期'], format='%Y年%m月%d日')
eq['地震時間'] = pd.to_datetime(eq['地震時間'], format='%H:%M')

DT = eq.groupby(['地震日期', '地震時間']).size()
duplicates = DT[DT >= 2] #找出重複的地震資料
#set_index將原始地震資料的索引設置為日期和時間的多重索引
#isin將重複出現過的日期和時間的索引與原始地震資料的索引進行比較，從而找出重複的地震資料
result = eq[eq.set_index(['地震日期', '地震時間']).index.isin(duplicates.index)]
result
# Out:
#          編號       地震日期                地震時間   經度(度E)   緯度(度N)  芮氏規模  深度(km)  \
# 19    第004號 2023-01-12 1900-01-01 13:15:00  120.660  22.8345   4.4    19.6
# 20  小區域有感地震 2023-01-12 1900-01-01 13:15:00  121.042  22.0660   4.1    25.2
# 34  小區域有感地震 2023-01-03 1900-01-01 05:46:00  120.341  23.1012   3.7    17.3
# 35  小區域有感地震 2023-01-03 1900-01-01 05:46:00  120.333  23.0953   3.5    16.9
#
#                                          位置
# 19  屏東縣政府東北方  24.4  公里 (位於屏東縣三地門鄉)(屏東縣三地門鄉)
# 20   臺東縣政府南方  77.1  公里 (位於臺灣東南部海域)(臺灣東南部海域)
# 34    臺南市政府東北方  20.0  公里 (位於臺南市山上區)(臺南市山上區)
# 35    臺南市政府東北方  19.0  公里 (位於臺南市山上區)(臺南市山上區)
